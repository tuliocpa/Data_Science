# %% [markdown]
# #                                                       Python Peers - Quick reference book
#
# ![python-socket-programming.png](attachment:python-socket-programming.png)

# %% [markdown]
# ## Importing and preparation of dataset

# %% [markdown]
# ### Loading a dataset

# %%
# Import pandas library
import pandas as pd

# Read the online file by the URL provides above, and assign it to variable "df"
other_path = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/auto.csv"
df = pd.read_csv(other_path, header=None)

# %% [markdown]
# ### Printing specific rows and fields of the dataset:

# %%
print("The first 5 rows of the dataframe") 
df.head(5)

#if you want to print the last values use df.tail(5)

# %% [markdown]
# ### Insert headers into dataset to replace numbers

# %%
# create headers list
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
print("headers\n", headers)

#Replace headers into the dataframe and print head value

df.columns = headers
df.head(10)

#if later you want to print the colums just go for: print(df.columns)

# %% [markdown]
# # Data analysis

# %% [markdown]
# ### If you want to drop a missing value in the dataset:

# %%
df.dropna(subset=["price"], axis=0, inplace = True)

# %% [markdown]
# ### Getting to know the data (describe and type)

# %%
#print all the datatypes on the dataset

df.dtypes

#Get general insights on the data (statitics summary)

dataframe.describe()

#or: 

dataframe.info

#just describe for itself limits the info on the type object items, to get info on them for for:

df.describe(include = "all")

#You can get specific insights on specific columns also:

df[['length','compression-ratio']].describe()

# %% [markdown]
# ### Getting to know the data (Len, iloc, Sum)

# %% [markdown]
# ### Example

# %%
def numeric_to_buckets(df, column_name):
    median = df[column_name].median()
    for i, val in enumerate(df[column_name]):
        if val >= median:
            df.loc[i, column_name] = 'high'
        else:
            df.loc[i, column_name] = 'low' 
            
for feature in df.columns[:-1]:
    numeric_to_buckets(df, feature)
    print(df.groupby(feature).quality.mean(), '\n')
